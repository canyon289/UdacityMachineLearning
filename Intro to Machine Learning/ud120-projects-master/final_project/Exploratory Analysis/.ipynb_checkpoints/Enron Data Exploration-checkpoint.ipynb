# %% [markdown]
# ## Exploring final dataset

# %%
import pickle
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib
matplotlib.style.use('ggplot')
pd.set_option('display.width', 180)
pd.set_option('display.max_columns', 500)

# data = pickle.load(open(r'../data/final_project_dataset_py3.p', 'rb'))
data = pickle.load(open(r'../data/final_project_dataset.pkl', 'rb'))

df = pd.DataFrame(data).transpose().replace({'NaN':np.nan})

# %%
#Check Dataframe Shape
df.shape
# Out:
# (146, 21)

# %%
#Dataframe Shape
df.size
# Out:
# 3066

# %%
#list Columns
df.columns
# Out:
# Index(['bonus', 'deferral_payments', 'deferred_income', 'director_fees', 'email_address', 'exercised_stock_options', 'expenses', 'from_messages', 'from_poi_to_this_person',
#        'from_this_person_to_poi', 'loan_advances', 'long_term_incentive', 'other', 'poi', 'restricted_stock', 'restricted_stock_deferred', 'salary', 'shared_receipt_with_poi',
#        'to_messages', 'total_payments', 'total_stock_value'],
#       dtype='object')

# %%
#Number of PO
df["poi"].sum()
# Out:
# 18

# %% [markdown]
# Taking a closer look at POI Data for a brief glance at the data columns and their values

# %%
df[df["poi"]]
# Out:
#                         bonus  deferral_payments  deferred_income  director_fees                 email_address  exercised_stock_options  expenses  from_messages  \
# BELDEN TIMOTHY N      5249999            2144013         -2334434            NaN          tim.belden@enron.com                   953136     17355            484
# BOWEN JR RAYMOND M    1350000                NaN             -833            NaN       raymond.bowen@enron.com                      NaN     65907             27
# CALGER CHRISTOPHER F  1250000                NaN          -262500            NaN  christopher.calger@enron.com                      NaN     35818            144
# CAUSEY RICHARD A      1000000                NaN          -235000            NaN      richard.causey@enron.com                      NaN     30674             49
# COLWELL WESLEY        1200000              27610          -144062            NaN         wes.colwell@enron.com                      NaN     16514             40
# DELAINEY DAVID W      3000000                NaN              NaN            NaN      david.delainey@enron.com                  2291113     86174           3069
# FASTOW ANDREW S       1300000                NaN         -1386055            NaN       andrew.fastow@enron.com                      NaN     55921            NaN
# GLISAN JR BEN F        600000                NaN              NaN            NaN          ben.glisan@enron.com                   384728    125978             16
# HANNON KEVIN P        1500000                NaN         -3117011            NaN        kevin.hannon@enron.com                  5538001     34039             32
# HIRKO JOSEPH              NaN              10259              NaN            NaN           joe.hirko@enron.com                 30766064     77978            NaN
# KOENIG MARK E          700000                NaN              NaN            NaN         mark.koenig@enron.com                   671737    127017             61
# KOPPER MICHAEL J       800000                NaN              NaN            NaN      michael.kopper@enron.com                      NaN    118134            NaN
# LAY KENNETH L         7000000             202911          -300000            NaN         kenneth.lay@enron.com                 34348384     99832             36
# RICE KENNETH D        1750000                NaN         -3504386            NaN            ken.rice@enron.com                 19794175     46950             18
# RIEKER PAULA H         700000             214678          -100000            NaN        paula.rieker@enron.com                  1635238     33271             82
# SHELBY REX             200000                NaN            -4167            NaN          rex.shelby@enron.com                  1624396     22884             39
# SKILLING JEFFREY K    5600000                NaN              NaN            NaN       jeff.skilling@enron.com                 19250000     29336            108
# YEAGER F SCOTT            NaN                NaN              NaN            NaN        scott.yeager@enron.com                  8308552     53947            NaN
#
#                       from_poi_to_this_person  from_this_person_to_poi  loan_advances  long_term_incentive     other   poi  restricted_stock  restricted_stock_deferred   salary  \
# BELDEN TIMOTHY N                          228                      108            NaN                  NaN    210698  True            157569                        NaN   213999
# BOWEN JR RAYMOND M                        140                       15            NaN               974293      1621  True            252055                        NaN   278601
# CALGER CHRISTOPHER F                      199                       25            NaN               375304       486  True            126027                        NaN   240189
# CAUSEY RICHARD A                           58                       12            NaN               350000    307895  True           2502063                        NaN   415189
# COLWELL WESLEY                            240                       11            NaN                  NaN    101740  True            698242                        NaN   288542
# DELAINEY DAVID W                           66                      609            NaN              1294981      1661  True           1323148                        NaN   365163
# FASTOW ANDREW S                           NaN                      NaN            NaN              1736055    277464  True           1794412                        NaN   440698
# GLISAN JR BEN F                            52                        6            NaN                71023    200308  True            393818                        NaN   274975
# HANNON KEVIN P                             32                       21            NaN              1617011     11350  True            853064                        NaN   243293
# HIRKO JOSEPH                              NaN                      NaN            NaN                  NaN      2856  True               NaN                        NaN      NaN
# KOENIG MARK E                              53                       15            NaN               300000    150458  True           1248318                        NaN   309946
# KOPPER MICHAEL J                          NaN                      NaN            NaN               602671    907502  True            985032                        NaN   224305
# LAY KENNETH L                             123                       16       81525000              3600000  10359729  True          14761694                        NaN  1072321
# RICE KENNETH D                             42                        4            NaN              1617011    174839  True           2748364                        NaN   420636
# RIEKER PAULA H                             35                       48            NaN                  NaN      1950  True            283649                        NaN   249201
# SHELBY REX                                 13                       14            NaN                  NaN   1573324  True            869220                        NaN   211844
# SKILLING JEFFREY K                         88                       30            NaN              1920000     22122  True           6843672                        NaN  1111258
# YEAGER F SCOTT                            NaN                      NaN            NaN                  NaN    147950  True           3576206                        NaN   158403
#
#                       shared_receipt_with_poi  to_messages  total_payments  total_stock_value
# BELDEN TIMOTHY N                         5521         7991         5501630            1110705
# BOWEN JR RAYMOND M                       1593         1858         2669589             252055
# CALGER CHRISTOPHER F                     2188         2598         1639297             126027
# CAUSEY RICHARD A                         1585         1892         1868758            2502063
# COLWELL WESLEY                           1132         1758         1490344             698242
# DELAINEY DAVID W                         2097         3093         4747979            3614261
# FASTOW ANDREW S                           NaN          NaN         2424083            1794412
# GLISAN JR BEN F                           874          873         1272284             778546
# HANNON KEVIN P                           1035         1045          288682            6391065
# HIRKO JOSEPH                              NaN          NaN           91093           30766064
# KOENIG MARK E                            2271         2374         1587421            1920055
# KOPPER MICHAEL J                          NaN          NaN         2652612             985032
# LAY KENNETH L                            2411         4273       103559793           49110078
# RICE KENNETH D                            864          905          505050           22542539
# RIEKER PAULA H                           1258         1328         1099100            1918887
# SHELBY REX                                 91          225         2003885            2493616
# SKILLING JEFFREY K                       2042         3627         8682716           26093672
# YEAGER F SCOTT                            NaN          NaN          360300           11884758

# %% [markdown]
# Sort dataframe to see who got paid the highest salary

# %%
salary = df["salary"].copy()
salary.dropna().sort(inplace = False)
# Out:
# c:\miniconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort is deprecated, use sort_values(inplace=True) for for INPLACE sorting
#   from ipykernel import kernelapp as app
# BANNANTINE JAMES M                  477
# GRAY RODNEY                        6615
# WESTFAHL RICHARD K                63744
# REYNOLDS LAWRENCE                 76399
# BAZELIDES PHILIP J                80818
# IZZO LAWRENCE L                   85274
# OVERDYKE JR JERE C                94941
# REDMOND BRIAN L                   96840
# HUMPHREY GENE E                  130724
# YEAGER F SCOTT                   158403
# SULLIVAN-SHAKLOVITZ COLLEEN      162779
# ELLIOTT STEVEN                   170941
# KISHKILL JOSEPH G                174246
# ECHOLS JOHN B                    182245
# CUMBERLAND MICHAEL S             184899
# BERGSIEKER RICHARD P             187922
# GAHN ROBERT S                    192008
# PIPER GREGORY F                  197091
# FITZGERALD JAY L                 199157
# ALLEN PHILLIP K                  201955
# DEFFNER JOSEPH M                 206121
# DETMERING TIMOTHY J              210500
# DURAN WILLIAM D                  210692
# HICKERSON GARY J                 211788
# SHELBY REX                       211844
# BIBI PHILIPPE A                  213625
# BELDEN TIMOTHY N                 213999
# BERBERIAN DAVID                  216582
# DODSON KEITH                     221003
# THORN TERENCE H                  222093
#                                  ...
# COLWELL WESLEY                   288542
# JACKSON CHARLENE R               288558
# UMANOFF ADAM S                   288589
# SHANKMAN JEFFREY A               304110
# FALLON JAMES B                   304588
# KOENIG MARK E                    309946
# COX DAVID                        314288
# WHITE JR THOMAS E                317543
# OLSON CINDY K                    329078
# BUY RICHARD B                    330546
# LAVORATO JOHN J                  339288
# MARTIN AMANDA K                  349487
# WALLS JR ROBERT H                357091
# MCCONNELL MICHAEL S              365038
# DELAINEY DAVID W                 365163
# METTS MARK                       365788
# MCMAHON JEFFREY                  370448
# HAEDICKE MARK E                  374125
# KEAN STEVEN J                    404338
# CAUSEY RICHARD A                 415189
# RICE KENNETH D                   420636
# SHERRIFF JOHN R                  428780
# FASTOW ANDREW S                  440698
# DERRICK JR. JAMES V              492375
# WHALLEY LAWRENCE G               510364
# PICKERING MARK R                 655037
# FREVERT MARK A                  1060932
# LAY KENNETH L                   1072321
# SKILLING JEFFREY K              1111258
# TOTAL                          26704229
# Name: salary, dtype: float64

# %% [markdown]
# Found total value which is erroneous. Dropping from dataframe

# %%
df.drop("TOTAL", inplace=True)
df.shape
# Out:
# (145, 21)

# %%
list(df.index)
# Out:
# ['ALLEN PHILLIP K',
#  'BADUM JAMES P',
#  'BANNANTINE JAMES M',
#  'BAXTER JOHN C',
#  'BAY FRANKLIN R',
#  'BAZELIDES PHILIP J',
#  'BECK SALLY W',
#  'BELDEN TIMOTHY N',
#  'BELFER ROBERT',
#  'BERBERIAN DAVID',
#  'BERGSIEKER RICHARD P',
#  'BHATNAGAR SANJAY',
#  'BIBI PHILIPPE A',
#  'BLACHMAN JEREMY M',
#  'BLAKE JR. NORMAN P',
#  'BOWEN JR RAYMOND M',
#  'BROWN MICHAEL',
#  'BUCHANAN HAROLD G',
#  'BUTTS ROBERT H',
#  'BUY RICHARD B',
#  'CALGER CHRISTOPHER F',
#  'CARTER REBECCA C',
#  'CAUSEY RICHARD A',
#  'CHAN RONNIE',
#  'CHRISTODOULOU DIOMEDES',
#  'CLINE KENNETH W',
#  'COLWELL WESLEY',
#  'CORDES WILLIAM R',
#  'COX DAVID',
#  'CUMBERLAND MICHAEL S',
#  'DEFFNER JOSEPH M',
#  'DELAINEY DAVID W',
#  'DERRICK JR. JAMES V',
#  'DETMERING TIMOTHY J',
#  'DIETRICH JANET R',
#  'DIMICHELE RICHARD G',
#  'DODSON KEITH',
#  'DONAHUE JR JEFFREY M',
#  'DUNCAN JOHN H',
#  'DURAN WILLIAM D',
#  'ECHOLS JOHN B',
#  'ELLIOTT STEVEN',
#  'FALLON JAMES B',
#  'FASTOW ANDREW S',
#  'FITZGERALD JAY L',
#  'FOWLER PEGGY',
#  'FOY JOE',
#  'FREVERT MARK A',
#  'FUGH JOHN L',
#  'GAHN ROBERT S',
#  'GARLAND C KEVIN',
#  'GATHMANN WILLIAM D',
#  'GIBBS DANA R',
#  'GILLIS JOHN',
#  'GLISAN JR BEN F',
#  'GOLD JOSEPH',
#  'GRAMM WENDY L',
#  'GRAY RODNEY',
#  'HAEDICKE MARK E',
#  'HANNON KEVIN P',
#  'HAUG DAVID L',
#  'HAYES ROBERT E',
#  'HAYSLETT RODERICK J',
#  'HERMANN ROBERT J',
#  'HICKERSON GARY J',
#  'HIRKO JOSEPH',
#  'HORTON STANLEY C',
#  'HUGHES JAMES A',
#  'HUMPHREY GENE E',
#  'IZZO LAWRENCE L',
#  'JACKSON CHARLENE R',
#  'JAEDICKE ROBERT',
#  'KAMINSKI WINCENTY J',
#  'KEAN STEVEN J',
#  'KISHKILL JOSEPH G',
#  'KITCHEN LOUISE',
#  'KOENIG MARK E',
#  'KOPPER MICHAEL J',
#  'LAVORATO JOHN J',
#  'LAY KENNETH L',
#  'LEFF DANIEL P',
#  'LEMAISTRE CHARLES',
#  'LEWIS RICHARD',
#  'LINDHOLM TOD A',
#  'LOCKHART EUGENE E',
#  'LOWRY CHARLES P',
#  'MARTIN AMANDA K',
#  'MCCARTY DANNY J',
#  'MCCLELLAN GEORGE',
#  'MCCONNELL MICHAEL S',
#  'MCDONALD REBECCA',
#  'MCMAHON JEFFREY',
#  'MENDELSOHN JOHN',
#  'METTS MARK',
#  'MEYER JEROME J',
#  'MEYER ROCKFORD G',
#  'MORAN MICHAEL P',
#  'MORDAUNT KRISTINA M',
#  'MULLER MARK S',
#  'MURRAY JULIA H',
#  'NOLES JAMES L',
#  'OLSON CINDY K',
#  'OVERDYKE JR JERE C',
#  'PAI LOU L',
#  'PEREIRA PAULO V. FERRAZ',
#  'PICKERING MARK R',
#  'PIPER GREGORY F',
#  'PIRO JIM',
#  'POWERS WILLIAM',
#  'PRENTICE JAMES',
#  'REDMOND BRIAN L',
#  'REYNOLDS LAWRENCE',
#  'RICE KENNETH D',
#  'RIEKER PAULA H',
#  'SAVAGE FRANK',
#  'SCRIMSHAW MATTHEW',
#  'SHANKMAN JEFFREY A',
#  'SHAPIRO RICHARD S',
#  'SHARP VICTORIA T',
#  'SHELBY REX',
#  'SHERRICK JEFFREY B',
#  'SHERRIFF JOHN R',
#  'SKILLING JEFFREY K',
#  'STABLER FRANK',
#  'SULLIVAN-SHAKLOVITZ COLLEEN',
#  'SUNDE MARTIN',
#  'TAYLOR MITCHELL S',
#  'THE TRAVEL AGENCY IN THE PARK',
#  'THORN TERENCE H',
#  'TILNEY ELIZABETH A',
#  'UMANOFF ADAM S',
#  'URQUHART JOHN A',
#  'WAKEHAM JOHN',
#  'WALLS JR ROBERT H',
#  'WALTERS GARETH W',
#  'WASAFF GEORGE',
#  'WESTFAHL RICHARD K',
#  'WHALEY DAVID A',
#  'WHALLEY LAWRENCE G',
#  'WHITE JR THOMAS E',
#  'WINOKUR JR. HERBERT S',
#  'WODRASKA JOHN',
#  'WROBEL BRUCE',
#  'YEAGER F SCOTT',
#  'YEAP SOON']

# %%
df.ix['THE TRAVEL AGENCY IN THE PARK']
# Out:
# bonus                           NaN
# deferral_payments               NaN
# deferred_income                 NaN
# director_fees                   NaN
# email_address                   NaN
# exercised_stock_options         NaN
# expenses                        NaN
# from_messages                   NaN
# from_poi_to_this_person         NaN
# from_this_person_to_poi         NaN
# loan_advances                   NaN
# long_term_incentive             NaN
# other                        362096
# poi                           False
# restricted_stock                NaN
# restricted_stock_deferred       NaN
# salary                          NaN
# shared_receipt_with_poi         NaN
# to_messages                     NaN
# total_payments               362096
# total_stock_value               NaN
# Name: THE TRAVEL AGENCY IN THE PARK, dtype: object

# %%
df.drop('THE TRAVEL AGENCY IN THE PARK', inplace=True)

# %% [markdown]
# ## Deeper Exploratory Analysis
# Now that I am more comfortable with my dataframe I would like to start exploring the difference between POI and non POI people

# %%
#Create POI Groupby Object
poi_group = df.groupby("poi")

# %% [markdown]
# ### Null value results
# Checking null values we see some interesting things. The POI seem to have more deferred income, no director fees, no restricted stock versus non person of interest.
#
# They all also seem to have  much greate proportion of Other types of compensation

# %%
#Check NAN values in each group
# poi_group.apply(lambda x: (x.notnull().sum())/len(x)).transpose()
poi_group.apply(lambda x: (x.notnull().sum())/len(x)).transpose().plot(kind ="bar", figsize = (17,10))

# %%
missing_data = poi_group.apply(lambda x: (x.notnull().sum())/len(x)).transpose()
print(missing_data)
(missing_data[True] - missing_data[False]).sort_values()
# Out:
# poi                           False     True
# bonus                      0.515873  0.888889
# deferral_payments          0.261905  0.277778
# deferred_income            0.293651  0.611111
# director_fees              0.126984  0.000000
# email_address              0.738095  1.000000
# exercised_stock_options    0.706349  0.666667
# expenses                   0.603175  1.000000
# from_messages              0.571429  0.777778
# from_poi_to_this_person    0.571429  0.777778
# from_this_person_to_poi    0.571429  0.777778
# loan_advances              0.015873  0.055556
# long_term_incentive        0.420635  0.666667
# other                      0.579365  1.000000
# poi                        1.000000  1.000000
# restricted_stock           0.730159  0.944444
# restricted_stock_deferred  0.134921  0.000000
# salary                     0.611111  0.944444
# shared_receipt_with_poi    0.571429  0.777778
# to_messages                0.571429  0.777778
# total_payments             0.833333  1.000000
# total_stock_value          0.849206  1.000000
# restricted_stock_deferred   -0.134921
# director_fees               -0.126984
# exercised_stock_options     -0.039683
# poi                          0.000000
# deferral_payments            0.015873
# loan_advances                0.039683
# total_stock_value            0.150794
# total_payments               0.166667
# from_messages                0.206349
# from_poi_to_this_person      0.206349
# from_this_person_to_poi      0.206349
# shared_receipt_with_poi      0.206349
# to_messages                  0.206349
# restricted_stock             0.214286
# long_term_incentive          0.246032
# email_address                0.261905
# deferred_income              0.317460
# salary                       0.333333
# bonus                        0.373016
# expenses                     0.396825
# other                        0.420635
# dtype: float64

# %% [markdown]
# Let's compare distribution as well by looking at boxplots

# %%
p_df = df.fillna(0)
for col in df.columns:
    if col not in ["poi", "email_address" ]:
        df[["poi", col]].boxplot(by="poi", figsize = (10,10))

# %% [markdown]
# There seem to be some outliers in salary, total_payments, and restricted stock. Checking those values

# %%
df["total_payments"].copy().dropna().sort(inplace = False)
# Out:
# c:\miniconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort is deprecated, use sort_values(inplace=True) for for INPLACE sorting
#   if __name__ == '__main__':
# MENDELSOHN JOHN                  148
# HAUG DAVID L                     475
# BLAKE JR. NORMAN P              1279
# MEYER JEROME J                  2151
# SAVAGE FRANK                    3750
# HAYES ROBERT E                  7961
# PEREIRA PAULO V. FERRAZ        27942
# BROWN MICHAEL                  49288
# FUGH JOHN L                    50591
# YEAP SOON                      55097
# DUNCAN JOHN H                  77492
# JAEDICKE ROBERT                83750
# WINOKUR JR. HERBERT S          84992
# WALTERS GARETH W               87410
# LEMAISTRE CHARLES              87492
# HIRKO JOSEPH                   91093
# BELFER ROBERT                 102500
# REDMOND BRIAN L               111529
# GRAMM WENDY L                 119292
# FOY JOE                       181755
# BADUM JAMES P                 182466
# WODRASKA JOHN                 189583
# ELLIOTT STEVEN                211725
# WAKEHAM JOHN                  213071
# BERBERIAN DAVID               228474
# URQUHART JOHN A               228656
# OVERDYKE JR JERE C            249787
# HANNON KEVIN P                288682
# DODSON KEITH                  319941
# YEAGER F SCOTT                360300
#                              ...
# MCCONNELL MICHAEL S          2101364
# GOLD JOSEPH                  2146973
# BUY RICHARD B                2355702
# DIMICHELE RICHARD G          2368151
# FASTOW ANDREW S              2424083
# KOPPER MICHAEL J             2652612
# LEFF DANIEL P                2664228
# BOWEN JR RAYMOND M           2669589
# ECHOLS JOHN B                2692324
# SHANKMAN JEFFREY A           3038702
# HUMPHREY GENE E              3100224
# PAI LOU L                    3123383
# HORTON STANLEY C             3131860
# MULLER MARK S                3202070
# KITCHEN LOUISE               3471141
# FALLON JAMES B               3676340
# HAEDICKE MARK E              3859065
# MCMAHON JEFFREY              4099771
# SHERRIFF JOHN R              4335388
# ALLEN PHILLIP K              4484442
# WHALLEY LAWRENCE G           4677574
# DELAINEY DAVID W             4747979
# BELDEN TIMOTHY N             5501630
# BAXTER JOHN C                5634343
# MARTIN AMANDA K              8407016
# SKILLING JEFFREY K           8682716
# LAVORATO JOHN J             10425757
# BHATNAGAR SANJAY            15456290
# FREVERT MARK A              17252530
# LAY KENNETH L              103559793
# Name: total_payments, dtype: float64

# %% [markdown]
# Based off this quick exploratory analysis I'll be using deferred income, director fees, restricted stock, other and exercised stock options as my user selected features

# %% [markdown]
# ## Helpful Resources
# http://stackoverflow.com/questions/25250654/how-can-i-use-a-custom-feature-selection-function-in-scikit-learns-pipeline
#
# #### Feature Selection Example
# http://machinelearningmastery.com/feature-selection-in-python-with-scikit-learn/
#
# #### Feature Union Documentation
# http://scikit-learn.org/dev/modules/generated/sklearn.pipeline.FeatureUnion.html#sklearn.pipeline.FeatureUnion
